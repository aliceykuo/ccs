# %%
import pandas as pd

# %%
cd data
# Out:
# /Users/kuoyen/Documents/myweddingstyle/data

# %%
df = pd.read_csv('vintagedata.csv')

# %%
df.head()
# Out:
#                                   ﻿"large_image.alt"  \
# 0                                        That dress!
# 1   Future Wedding - simple traditional wedding cake
# 2  Invitatios on: http://www.minted.comStorybook ...
# 3  This would make a cute picture while you are g...
# 4  Love this vintage eclectic cake display! // ph...
#
#                                      large_image.src  \
# 0  https://s-media-cache-ak0.pinimg.com/736x/61/4...
# 1  https://s-media-cache-ak0.pinimg.com/736x/5c/0...
# 2  https://s-media-cache-ak0.pinimg.com/736x/3c/6...
# 3  https://s-media-cache-ak0.pinimg.com/736x/d3/f...
# 4  https://s-media-cache-ak0.pinimg.com/736x/62/3...
#
#                                     large_image.href  large_image.text  \
# 0   http://futurewedding.tumblr.com/post/37051002781               NaN
# 1   http://futurewedding.tumblr.com/post/54374802394               NaN
# 2  http://www.minted.com/product/letterpress-wedd...               NaN
# 3  http://www.utahbrideblog.com/utah-vendors/wedd...               NaN
# 4  http://theeverylastdetail.com/vintage-eclectic...               NaN
#
#                                           title.href  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  http://theeverylastdetail.com/vintage-eclectic...
#
#                             title.text  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4  Vintage Eclectic California Wedding
#
#                                             tag_desc  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Set in an old factory building, today’s vintag...
#
#                                      ogi_pinner.href        ogi_pinner.text  \
# 0  https://www.pinterest.com/minted/vintage-wedding/        Vintage Wedding
# 1  https://www.pinterest.com/minted/vintage-wedding/        Vintage Wedding
# 2                                                NaN                    NaN
# 3  https://www.pinterest.com/LaurenRennells/vinta...  Vintage Wedding Ideas
# 4  http://theeverylastdetail.com/vintage-eclectic...      Every Last Detail
#
#                                      board_name.href board_name.texthref"  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4  https://www.pinterest.com/minted/vintage-wedding/      Vintage Wedding
#
#    board_name.text
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
# df.columns = ['pin_desc', 'img_url', 'img_href', 'img_text', 'title_href', 'title_text', 'tag_desc', 'orig_pinner_href','orig_pinner', 'board_name_href', 'board_name']

#

# %%
df.head(2)
# Out:
#                                  ﻿"large_image.alt"  \
# 0                                       That dress!
# 1  Future Wedding - simple traditional wedding cake
#
#                                      large_image.src  \
# 0  https://s-media-cache-ak0.pinimg.com/736x/61/4...
# 1  https://s-media-cache-ak0.pinimg.com/736x/5c/0...
#
#                                    large_image.href  large_image.text  \
# 0  http://futurewedding.tumblr.com/post/37051002781               NaN
# 1  http://futurewedding.tumblr.com/post/54374802394               NaN
#
#   title.href title.text tag_desc  \
# 0        NaN        NaN      NaN
# 1        NaN        NaN      NaN
#
#                                      ogi_pinner.href  ogi_pinner.text  \
# 0  https://www.pinterest.com/minted/vintage-wedding/  Vintage Wedding
# 1  https://www.pinterest.com/minted/vintage-wedding/  Vintage Wedding
#
#   board_name.href board_name.texthref"  board_name.text
# 0             NaN                  NaN              NaN
# 1             NaN                  NaN              NaN
