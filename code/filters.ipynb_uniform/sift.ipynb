# %%
import cv2
import numpy as np
from skimage import io
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.color import rgb2gray

img = io.imread('/Users/kuoyen/Desktop/beachsamp1.jpg')
print "original shape", img.shape
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT()
kp = sift.detect(gray,None)
# print sum(img)
img=cv2.drawKeypoints(gray,kp)
print sum(img)

cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints.jpg',img)
kp, des = sift.detectAndCompute(gray,None)
print "des shape", des.shape
print "kp shape", kp.shape
# img=cv2.drawKeypoints(gray,kp,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints2.jpg',img)
# Out:
# original shape (750, 500, 3)
# [[146 146 146]
#  [152 218 211]
#  [114 108 120]
#  ...,
#  [ 11  17  76]
#  [191 213 196]
#  [ 22  22  22]]
# des shape
#  (1198, 128)
# kp shape
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-1ccb68f1ab7e> in <module>()
#      19 kp, des = sift.detectAndCompute(gray,None)
#      20 print "des shape", des.shape
# ---> 21 print "kp shape", kp.shape
#      22 # img=cv2.drawKeypoints(gray,kp,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#      23 # cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints2.jpg',img)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
img = io.imread('/Users/kuoyen/Desktop/sift_keypoints.jpg')
img.shape
plt.imshow(img)

# %%
img = io.imread('/Users/kuoyen/Desktop/sift_keypoints2.jpg')
img.shape
plt.imshow(img)

# %%
img = io.imread('/Users/kuoyen/Desktop/beachsamp1.jpg')
print "original shape", img.shape
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
sift = cv2.SIFT()
kp = sift.detect(gray,None)
print img
print "*************"
img=cv2.drawKeypoints(gray,kp)
print img

# cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints.jpg',img)
# kp, des = sift.detectAndCompute(gray,None)
# print "des shape", des.shape
# print "kp shape", kp.shape
# Out:
# original shape (750, 500, 3)
# [[[128 182 228]
#   [128 182 228]
#   [128 182 228]
#   ...,
#   [141 189 227]
#   [141 189 227]
#   [141 189 227]]
#
#  [[128 182 228]
#   [128 182 228]
#   [128 182 228]
#   ...,
#   [142 190 228]
#   [142 190 228]
#   [142 190 228]]
#
#  [[128 182 228]
#   [128 182 228]
#   [129 183 229]
#   ...,
#   [145 190 229]
#   [145 190 229]
#   [145 190 229]]
#
#  ...,
#  [[237 232 226]
#   [235 230 224]
#   [231 224 218]
#   ...,
#   [180 173 163]
#   [211 204 194]
#   [227 220 210]]
#
#  [[222 213 204]
#   [230 221 212]
#   [235 226 217]
#   ...,
#   [192 185 175]
#   [217 210 200]
#   [224 217 207]]
#
#  [[242 229 220]
#   [241 228 219]
#   [236 223 214]
#   ...,
#   [223 216 206]
#   [234 227 217]
#   [226 219 209]]]
# *************
# [[[190 190 190]
#   [190 190 190]
#   [190 190 190]
#   ...,
#   [195 195 195]
#   [195 195 195]
#   [195 195 195]]
#
#  [[190 190 190]
#   [190 190 190]
#   [190 190 190]
#   ...,
#   [196 196 196]
#   [196 196 196]
#   [196 196 196]]
#
#  [[190 190 190]
#   [190 190 190]
#   [191 191 191]
#   ...,
#   [197 197 197]
#   [197 197 197]
#   [197 197 197]]
#
#  ...,
#  [[231 231 231]
#   [229 229 229]
#   [194 215 225]
#   ...,
#   [171 171 171]
#   [202 202 202]
#   [218 218 218]]
#
#  [[211 211 211]
#   [219 219 219]
#   [224 224 224]
#   ...,
#   [183 183 183]
#   [208 208 208]
#   [215 215 215]]
#
#  [[228 228 228]
#   [227 227 227]
#   [222 222 222]
#   ...,
#   [214 214 214]
#   [225 225 225]
#   [217 217 217]]]
