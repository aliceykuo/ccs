# %%
import cv2
import numpy as np
from skimage import io
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.color import rgb2gray
from skimage import io
from skimage.filters import roberts, sobel, scharr, canny 


img = io.imread('/Users/kuoyen/Desktop/beachsamp1.jpg')
print "original shape", img.shape
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT()
kp = sift.detect(gray,None)
# print sum(img)
img=cv2.drawKeypoints(gray,kp)
print sum(img)

cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints.jpg',img)
kp, des = sift.detectAndCompute(gray,None)
print "des shape", des.shape
print "kp shape", kp.shape
# img=cv2.drawKeypoints(gray,kp,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints2.jpg',img)
# Out:
# original shape (750, 500, 3)
# [[146 146 146]
#  [206 126 229]
#  [167   3  71]
#  ...,
#  [178 121 159]
#  [205  52 149]
#  [ 18  20  24]]
# des shape
#  (1198, 128)
# kp shape
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a27664cd3ab0> in <module>()
#      22 kp, des = sift.detectAndCompute(gray,None)
#      23 print "des shape", des.shape
# ---> 24 print "kp shape", kp.shape
#      25 # img=cv2.drawKeypoints(gray,kp,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#      26 # cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints2.jpg',img)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
img = io.imread('/Users/kuoyen/Desktop/sift_keypoints.jpg')
img.shape
plt.imshow(img)

# %%
img = io.imread('/Users/kuoyen/Desktop/sift_keypoints2.jpg')
img.shape
plt.imshow(img)

# %%
img = io.imread('/Users/kuoyen/Desktop/beachsamp1.jpg')
print "original shape", img.shape
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
sift = cv2.SIFT()
kp = sift.detect(gray,None)
print img
print "*************"
img=cv2.drawKeypoints(gray,kp)
# print img

# cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints.jpg',img)
# kp, des = sift.detectAndCompute(gray,None)
# print "des shape", des.shape
# print "kp shape", kp.shape
# Out:
# original shape (750, 500, 3)
# [[[128 182 228]
#   [128 182 228]
#   [128 182 228]
#   ...,
#   [141 189 227]
#   [141 189 227]
#   [141 189 227]]
#
#  [[128 182 228]
#   [128 182 228]
#   [128 182 228]
#   ...,
#   [142 190 228]
#   [142 190 228]
#   [142 190 228]]
#
#  [[128 182 228]
#   [128 182 228]
#   [129 183 229]
#   ...,
#   [145 190 229]
#   [145 190 229]
#   [145 190 229]]
#
#  ...,
#  [[237 232 226]
#   [235 230 224]
#   [231 224 218]
#   ...,
#   [180 173 163]
#   [211 204 194]
#   [227 220 210]]
#
#  [[222 213 204]
#   [230 221 212]
#   [235 226 217]
#   ...,
#   [192 185 175]
#   [217 210 200]
#   [224 217 207]]
#
#  [[242 229 220]
#   [241 228 219]
#   [236 223 214]
#   ...,
#   [223 216 206]
#   [234 227 217]
#   [226 219 209]]]
# *************
# [[[190 190 190]
#   [190 190 190]
#   [190 190 190]
#   ...,
#   [195 195 195]
#   [195 195 195]
#   [195 195 195]]
#
#  [[190 190 190]
#   [190 190 190]
#   [190 190 190]
#   ...,
#   [196 196 196]
#   [196 196 196]
# ...

# %%
img = io.imread('/Users/kuoyen/Documents/myweddingstyle/images/raw/beach/beach173.jpg')
img.shape
plt.imshow(img)

# %%
pwd
# Out:
# u'/Users/kuoyen/Documents/myweddingstyle/code/filters.ipynb_uniform'

# %%
img = io.imread('/Users/kuoyen/Documents/myweddingstyle/images/raw/beach/beach173.jpg')
print "original shape", img.shape
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT()
kp = sift.detect(gray,None)
# print sum(img)
img=cv2.drawKeypoints(gray,kp)
# print sum(img)

cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints.jpg',img)
kp, des = sift.detectAndCompute(gray,None)
img=cv2.drawKeypoints(gray,kp,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv2.imwrite('/Users/kuoyen/Desktop/sift_keypoints2.jpg',img)
# Out:
# original shape (407, 610, 3)
# True

# %%
sift = io.imread('/Users/kuoyen/Desktop/sift_keypoints.jpg')
io.imshow(sift)

# %%
sift = io.imread('/Users/kuoyen/Desktop/sift_keypoints2.jpg')
io.imshow(sift)

# %%
img = io.imread('/Users/kuoyen/Documents/myweddingstyle/images/raw/beach/beach173.jpg')
img = rgb2gray(img)
# plt.imshow(img, cmap=plt.cm.gray)
edge_roberts = roberts(img)
edge_sobel = sobel(img)
edge_canny = canny(img)
edge_scharr = scharr(img)
plt.imshow(edge_canny, cmap=plt.cm.gray)
# Out:
# /Users/kuoyen/anaconda/lib/python2.7/site-packages/skimage/filters/__init__.py:27: skimage_deprecation: Call to deprecated function ``canny``. Use ``skimage.feature.canny`` instead.
#   def canny(*args, **kwargs):
