# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/rustic_1.csv')

# %%
df2 = pd.read_csv('data/rustic_2.csv')

# %%
pwd
# Out:
# u'/Users/kuoyen/Documents/capstone/image_train'

# %%
df2.shape
# Out:
# (1208, 4)

# %%
df1.head()
# Out:
#                                         ﻿"image.alt"  \
# 0  A protea centerpiece with eye-popping texture ...
# 1  Farmhouse Chic Winery Wedding - this arrangeme...
# 2  Rustic Birch Themed Cake - Get the cake topper...
# 3  A wedding at Riley's farm in Oak Glen, CA.  Th...
# 4  Grayed jade wedding cake. Photo by Eddie Judd ...
#
#                                            image.src  \
# 0  https://s-media-cache-ak0.pinimg.com/236x/ab/f...
# 1  https://s-media-cache-ak0.pinimg.com/236x/dd/b...
# 2  https://s-media-cache-ak0.pinimg.com/236x/23/1...
# 3  https://s-media-cache-ak0.pinimg.com/236x/f2/e...
# 4  https://s-media-cache-ak0.pinimg.com/236x/d5/9...
#
#                                           image.href  image.text
# 0  https://www.pinterest.com/pin/389139224028517761/         NaN
# 1   https://www.pinterest.com/pin/62417144808571498/         NaN
# 2  https://www.pinterest.com/pin/144678206754478338/         NaN
# ...

# %%
df1.columns = ['desc', 'img_src', 'image_href', 'img_text']

# %%
df2.columns = ['img_href', 'title', 'desc_href', 'desc']

# %%
df1.head(1)
# Out:
#                                                 desc  \
# 0  A protea centerpiece with eye-popping texture ...
#
#                                              img_src  \
# 0  https://s-media-cache-ak0.pinimg.com/236x/ab/f...
#
#                                           image_href  img_text
# 0  https://www.pinterest.com/pin/389139224028517761/       NaN

# %%
df2.head(2)
# Out:
#                                        ﻿"title.href"  \
# 0  https://www.pinterest.com/pin/389139224028517761/
# 1   https://www.pinterest.com/pin/62417144808571498/
#
#                                           title.text  \
# 0  Wedding Ideas That Scream "Spring is Finally H...
# 1                                               0503
#
#                                          desc.href  \
# 0  https://www.pinterest.com/search?q=weddingdecor
# 1                                              NaN
#
#                                            desc.text
# 0  A protea centerpiece with eye-popping texture ...
# 1  Farmhouse Chic Winery Wedding - this arrangeme...

# %%
df = df1.merge(df2, on="desc")

# %%
df.head()
# Out:
#                                                 desc  \
# 0  A protea centerpiece with eye-popping texture ...
# 1  Grayed jade wedding cake. Photo by Eddie Judd ...
# 2                    watering can flower arrangement
# 3                                Rustic wedding sign
# 4                                Rustic Wedding Cake
#
#                                              img_src  \
# 0  https://s-media-cache-ak0.pinimg.com/236x/ab/f...
# 1  https://s-media-cache-ak0.pinimg.com/236x/d5/9...
# 2  https://s-media-cache-ak0.pinimg.com/236x/15/3...
# 3  https://s-media-cache-ak0.pinimg.com/236x/ca/f...
# 4  https://s-media-cache-ak0.pinimg.com/236x/56/d...
#
#                                           image_href  img_text  \
# 0  https://www.pinterest.com/pin/389139224028517761/       NaN
# 1  https://www.pinterest.com/pin/389139224028169332/       NaN
# 2  https://www.pinterest.com/pin/389139224027873840/       NaN
# 3  https://www.pinterest.com/pin/389139224027700459/       NaN
# ...

# %%
meta = pd.read_csv('data/beach_meta.csv')

# %%
meta.shape
# Out:
# (43, 11)

# %%
meta.head(2)
# meta['tag_desc'][1]
# Out:
#                                   ﻿"large_image.alt"  \
# 0  Elegant beach ceremony: http://www.stylemepret...
# 1  Romantic Cape Cod wedding: http://www.stylemep...
#
#                                      large_image.src  \
# 0  https://s-media-cache-ak0.pinimg.com/736x/a6/e...
# 1  https://s-media-cache-ak0.pinimg.com/736x/b8/f...
#
#                                     large_image.href  large_image.text  \
# 0  http://www.stylemepretty.com/2014/03/07/destin...               NaN
# 1  http://www.stylemepretty.com/massachusetts-wed...               NaN
#
#                                           title.href  \
# 0  http://www.stylemepretty.com/2014/03/07/destin...
# 1  http://www.stylemepretty.com/massachusetts-wed...
#
#                                        title.text  \
# 0  Destination Wedding in Puerto Vallarta, Mexico
# 1                      Whimsical Cape Cod Wedding
#
#                                             tag_desc  \
# ...

# %%
meta.columns = ['pin_desc', 'img_url', 'image_href', 'img_text', 'title_href', 'title_text', \
                'tag_desc', 'orig_pinner_href','orig_pinner', 'board_name_href', 'board_name']

# %%
meta.head()
# Out:
#                                             pin_desc  \
# 0  Elegant beach ceremony: http://www.stylemepret...
# 1  Romantic Cape Cod wedding: http://www.stylemep...
# 2  A beautiful welcome dinner dress: http://www.s...
# 3  Beach engagement: http://www.stylemepretty.com...
# 4  Lanterns and flowers line the beach aisle: htt...
#
#                                              img_url  \
# 0  https://s-media-cache-ak0.pinimg.com/736x/a6/e...
# 1  https://s-media-cache-ak0.pinimg.com/736x/b8/f...
# 2  https://s-media-cache-ak0.pinimg.com/736x/8f/5...
# 3  https://s-media-cache-ak0.pinimg.com/736x/28/4...
# 4  https://s-media-cache-ak0.pinimg.com/736x/ef/5...
#
#                                           image_href  img_text  \
# 0  http://www.stylemepretty.com/2014/03/07/destin...       NaN
# 1  http://www.stylemepretty.com/massachusetts-wed...       NaN
# 2  http://www.stylemepretty.com/2015/02/23/domini...       NaN
# 3  http://www.stylemepretty.com/2014/03/11/elegan...       NaN
# ...
