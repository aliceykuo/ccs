# %%
import pandas as pd

# %%
def merge_df(directory):
    file1 = 'data/'+ directory + '_1.csv'
    file2 = 'data/'+ directory + '_2.csv'
    df1 = pd.read_csv(file1)
    df2 = pd.read_csv(file2)
#     df = pd.merge(df1, df2)
    return df, df1, df2

# %%
df, df1, df2 = merge_df('rustic')
df.head()
# Out:
#                                         ﻿"image.alt"  \
# 0  A protea centerpiece with eye-popping texture ...
# 1  Farmhouse Chic Winery Wedding - this arrangeme...
# 2  Rustic Birch Themed Cake - Get the cake topper...
# 3  A wedding at Riley's farm in Oak Glen, CA.  Th...
# 4  Grayed jade wedding cake. Photo by Eddie Judd ...
#
#                                            image.src  \
# 0  https://s-media-cache-ak0.pinimg.com/236x/ab/f...
# 1  https://s-media-cache-ak0.pinimg.com/236x/dd/b...
# 2  https://s-media-cache-ak0.pinimg.com/236x/23/1...
# 3  https://s-media-cache-ak0.pinimg.com/236x/f2/e...
# 4  https://s-media-cache-ak0.pinimg.com/236x/d5/9...
#
#                                           image.href image.text
# 0  https://www.pinterest.com/pin/389139224028517761/        NaN
# 1   https://www.pinterest.com/pin/62417144808571498/        NaN
# 2  https://www.pinterest.com/pin/144678206754478338/        NaN
# 3  https://www.pinterest.com/pin/389139224028472488/        NaN
# ...

# %%
df1.head()
# Out:
#                                     ﻿"property3.alt"  \
# 0  Elegant beach ceremony: http://www.stylemepret...
# 1  Romantic Cape Cod wedding: http://www.stylemep...
# 2  A beautiful welcome dinner dress: http://www.s...
# 3  Beach engagement: http://www.stylemepretty.com...
# 4  Lanterns and flowers line the beach aisle: htt...
#
#                                        property3.src  \
# 0  https://s-media-cache-ak0.pinimg.com/236x/a6/e...
# 1  https://s-media-cache-ak0.pinimg.com/236x/b8/f...
# 2  https://s-media-cache-ak0.pinimg.com/236x/8f/5...
# 3  https://s-media-cache-ak0.pinimg.com/236x/28/4...
# 4  https://s-media-cache-ak0.pinimg.com/236x/ef/5...
#
#                                      property3.href property3.text
# 0  https://www.pinterest.com/pin/91620173646077017/            NaN
# 1  https://www.pinterest.com/pin/91620173646074482/            NaN
# 2  https://www.pinterest.com/pin/91620173646073556/            NaN
# ...

# %%
df2.head()
# Out:
#                                     ﻿"property3.alt"  \
# 0  Elegant beach ceremony: http://www.stylemepret...
# 1  Romantic Cape Cod wedding: http://www.stylemep...
# 2  A beautiful welcome dinner dress: http://www.s...
# 3  Beach engagement: http://www.stylemepretty.com...
# 4  Lanterns and flowers line the beach aisle: htt...
#
#                                        property3.src  \
# 0  https://s-media-cache-ak0.pinimg.com/236x/a6/e...
# 1  https://s-media-cache-ak0.pinimg.com/236x/b8/f...
# 2  https://s-media-cache-ak0.pinimg.com/236x/8f/5...
# 3  https://s-media-cache-ak0.pinimg.com/236x/28/4...
# 4  https://s-media-cache-ak0.pinimg.com/236x/ef/5...
#
#                                      property3.href property3.text
# 0  https://www.pinterest.com/pin/91620173646077017/            NaN
# 1  https://www.pinterest.com/pin/91620173646074482/            NaN
# 2  https://www.pinterest.com/pin/91620173646073556/            NaN
# ...

# %%
def merge_df(directory):
    file1_name = directory + '_1.csv'
    file2_name = directory + '_2.csv'
    df1 = pd.read_csv()
    df1 = pd.read_csv(file1)
    df2 = pd.read_csv(file2)
    df1.columns = ['desc', 'img_src', 'image_href', 'img_text']	
    df2.columns = ['img_href', 'title', 'desc_href', 'desc']
    df = df1.merge(df2, on="desc")
    return df
